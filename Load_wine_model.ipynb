# %%
import sklearn as klearn
import numpy as np
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

# %%
dataset = load_wine()
x_data = dataset.data
y_labels  = dataset.target

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x_data, y_labels, test_size = 0.2, shuffle = True, random_state = 12345)

# %%
xTrain = xTrain.astype("float32")
xTest = xTest.astype("float32")

# %%
import tensorflow as tf
import keras
from keras.layers import Dense
from keras import Sequential

# %%
model = Sequential()
model.add(Dense(xTrain.shape[0], activation = "relu"))
model.add(Dense(xTrain.shape[0]*2, activation = "relu"))
model.add(Dense(3, activation = "softmax"))

# %%
model.compile(loss = "sparse_categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
model.fit(xTrain, yTrain, batch_size = 20, epochs = 50)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5902 - accuracy: 0.8169
# Epoch 2/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6864 - accuracy: 0.8662
# Epoch 3/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6492 - accuracy: 0.8592
# Epoch 4/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4845 - accuracy: 0.9155
# Epoch 5/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2605 - accuracy: 0.9014
# Epoch 6/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.9366
# Epoch 7/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9366
# Epoch 8/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5249 - accuracy: 0.8873
# Epoch 9/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4033 - accuracy: 0.8803
# Epoch 10/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3730 - accuracy: 0.8944
# Epoch 11/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2061 - accuracy: 0.9225
# Epoch 12/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1386 - accuracy: 0.9437
# Epoch 13/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1983 - accuracy: 0.9155
# Epoch 14/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1497 - accuracy: 0.9155
# Epoch 15/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1884 - accuracy: 0.9225
# Epoch 16/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2157 - accuracy: 0.9155
# Epoch 17/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1673 - accuracy: 0.9507
# Epoch 18/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2899 - accuracy: 0.9014
# Epoch 19/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2298 - accuracy: 0.8944
# Epoch 20/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3213 - accuracy: 0.8592
# Epoch 21/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2754 - accuracy: 0.8873
# Epoch 22/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3261 - accuracy: 0.8944
# Epoch 23/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2280 - accuracy: 0.9155
# Epoch 24/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2210 - accuracy: 0.9366
# Epoch 25/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3800 - accuracy: 0.8732
# Epoch 26/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2195 - accuracy: 0.9155
# Epoch 27/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2119 - accuracy: 0.9225
# Epoch 28/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2172 - accuracy: 0.9225
# Epoch 29/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1822 - accuracy: 0.9296
# Epoch 30/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5675 - accuracy: 0.8451
# Epoch 31/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3149 - accuracy: 0.8732
# Epoch 32/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2499 - accuracy: 0.9296
# Epoch 33/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1335 - accuracy: 0.9577
# Epoch 34/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8803
# Epoch 35/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1492 - accuracy: 0.9577
# Epoch 36/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9225
# Epoch 37/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1390 - accuracy: 0.9225
# Epoch 38/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2503 - accuracy: 0.8873
# Epoch 39/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4173 - accuracy: 0.8944
# Epoch 40/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3025 - accuracy: 0.8873
# Epoch 41/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2097 - accuracy: 0.9296
# Epoch 42/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2070 - accuracy: 0.9366
# Epoch 43/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1206 - accuracy: 0.9507
# Epoch 44/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1880 - accuracy: 0.9366
# Epoch 45/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.9577
# Epoch 46/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2119 - accuracy: 0.9296
# Epoch 47/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1819 - accuracy: 0.9155
# Epoch 48/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1203 - accuracy: 0.9437
# Epoch 49/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9437
# Epoch 50/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1413 - accuracy: 0.9507

# %%
model.evaluate(xTest, yTest, batch_size =10)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2077 - accuracy: 0.8889
# [0.20765122771263123, 0.8888888955116272]
